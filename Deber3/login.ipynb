# %% [markdown]
# # LOGIN

# %% [markdown]
# IN THIS EXCERCISE WE HAVE TO INSPECT THE SCRIPT THAT VALIDATE THE LOGIN, IN THIS CASE IS 'index.js'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IN USERNAME WE HAVE AN ENCRYPT MESSAGE WITH BASE 64, SO WHE HAVE TO DECRYPT IT AND WE OBTAIN THE FLAG.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG: picoCTF{53rv3r_53rv3r_53rv3r_53rv3r_53rv3r}
