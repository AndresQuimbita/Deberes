# %% [markdown]
# # SEARCH SOURCE

# %% [markdown]
# WE HAVE TO FIND THE ARTIFACT THAT CONTAINS THE FLAG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IF WE INSPECT THE PAGE AND FOLLOW HE HINT WE COULD INFER THAT THE FLAG IS IN THE CSS FOLDER. IN THIS CASE WAS UN THE FILE 'style.css'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG: picoCTF{1nsp3ti0n_0f_w3bpag3s_ec95fa49}
