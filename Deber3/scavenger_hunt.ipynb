# %% [markdown]
# # SCAVENGER HUNT

# %% [markdown]
# IN THIS PICOCTF GIVE US THE NEXT WEB PAGE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IF WE CHOOSE WHAT GIVE US A SEQUENCE OF FILES THAT USE TO CREATE THE WEB PAGE. IF WE EXPLORE THE COMPONENTS OF THE WEB PAGE WE CAN CAPTURE THE FLAG.

# %% [markdown]
# ### HTML FILE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CSS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### JS

# %% [markdown]
# HERE WE HAVE A HINT INSTEAD THE FLAG.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# AFTER A RESEARCH, WE FIGURE OUT THAT WE HAVE TO EXPLORE THE FILE THAT CONTROL THE INDEX OF THE WEB PAGE, IN THIS CASE: robots.txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# THE NEXT PART IS IN THE FILE THAT USE THE APACHE SERVER.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# AND THE LAST PART IS THE FILE THAT STORE THE ATTRIBUTES OF THE WEB PAGE IN A FOLDER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG IS:   picoCTF{th4ts_4_l0t_0f_pl4c3s_2_lO0k_fa04427c}
