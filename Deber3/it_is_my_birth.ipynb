# %% [markdown]
# # IT IS MY BIRTHDAT

# %% [markdown]
# IN THIS EXCERCISE WE HAVE TO USE TO SMALL SIZE PDF TO FIND THE FLAG.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WHEN WE SEND 'UPLOAD', THE FILES ARE USED TO FIND COLLISION IN MD5 ENCRYPTER HASH

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG: picoCTF{c0ngr4ts_u_r_1nv1t3d_aad886b9}
