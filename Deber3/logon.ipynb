# %% [markdown]
# # LOGON

# %% [markdown]
# IN THIS EXCERCISE WE HAVE TO FIND THE WAY TO VALIDATE THE JOE's PASSWORD TO ACCESS TO THE FLAG.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WE SEND THE SIGN IN AND WE HACE THE NEXT RESPONSE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# INSPECT THE PAGE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WE CHANGE THE VALUE OF 'admin' TO 'True' AND REFRESH

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG: picoCTF{th3_c0nsp1r4cy_l1v3s_d1c24fef}
