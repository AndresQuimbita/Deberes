# %% [markdown]
# # LOCAL AUTHORITY

# %% [markdown]
# IN THIS EXCERCISE WE HAVE TO SEND THE LOGIN EVEN IF WE DO NOT KNOW THECORRECT USERNAME AND PASSWORD. AFTER THAT WE HAVE TO INSPECT THE FILE 'secure.js' THAT IS VISIBLE WITH THE WEB PAGE RESPONSE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WITH THIS WE CAN LOGIN WITH THE USERNAME 'admin' AND THE PASSWORD 'strongPassword098765'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG = picoCTF{j5_15_7r4n5p4r3n7_a8788e61}
