# %% [markdown]
# # COOKIES
#
# FOR THIS EXCERCISE PICOCTF GIVE US THE FOLLOWING WEB PAGE. FOR THE NAME OF THE TASK, WE HAVE TO INSPECT THE COOKIES OF THE PAGE.
#
# ### WEB PAGE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WE PUT THE EXAMPLE GIVE THERE TO ANALIZE THE COOKIES, THE RESPONSE OF THE WEB IS THIS PAGE AND WE SEE THE INSPECTOR AND ANALIZE THE COOKIES.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WE SEE A FIELD 'VALUE', IN THIS IF WE CHANGE THE VALUE AND REFRESH WE OBTAIN A DIFERENT MESSAGE IN THE WEB PAGE. IN THIS CASE VALUE = 1 IS FOR CHOCOLATE CHIP. IF WE EXPLORE THE VALUES WE OBTAIN THE FLAG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## THE FLAG

# %% [markdown]
# ![image.png](attachment:image.png)
