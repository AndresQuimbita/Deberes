# %% [markdown]
# # FIND ME

# %% [markdown]
# IN THIS EXCERCISE WE HAVE TO FIGURE OUT THE FLAG USING THE USERNAME test AND PASS test! TO ACCESS A NEW PAGE AFTER OF THE 'LOGIN'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WHEN WE SEND THE LOGIN, THE PAGE REALIZE TWO REDIRECTIN BEFORE TO SHOW THE TARGET WEB PAGE, IN THIS WE HAVE THE FLAG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# BUT IS BASE64 SO WE HAVE TO DECODE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MESSAGE ENCODE: cGljb0NURntwcm94aWVzX2FsbF90aGVfd2F5X2JlNzE2ZDhlfQ
#
# ### MESSAGE DECODE: picoCTF{proxies_all_the_way_be716d8e}
