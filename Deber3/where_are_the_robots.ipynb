# %% [markdown]
# # WHERE ARE THE ROBOTS

# %% [markdown]
# WE HAVE TO INSPECT IN THE WEB PAGE THE FILE 'robots.txt' that tell the creator.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WE HAVE TO REDIRECT THE WEB PAGE TO 'https://jupiter.challenges.picoctf.org/problem/36474//477ce.html' TO FIND THE FLAG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### THE FLAG: picoCTF{ca1cu1at1ng_Mach1n3s_477ce}
